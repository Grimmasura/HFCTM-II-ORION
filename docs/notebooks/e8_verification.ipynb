# %% [markdown]
# # E8 Verification Notebook
#
# Quick, deterministic checks for the MIH-IIE E8 lattice. The notebook mirrors the CI tests: counts, norms, inner products, and degree regularity of the <r_i, r_j> = 1 adjacency.

# %%
import os, sys
repo_root = os.path.abspath(os.path.join('..', '..'))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

from mih_iie.layers.l2_majorana_array import compute_e8_invariants, verify_e8_invariants

# %%
report = compute_e8_invariants()
report.summary()

# %%
checks = verify_e8_invariants(report)
all(checks.values()), checks

# %%
from collections import Counter

deg_counter = Counter(report.degrees)
sorted(deg_counter.items())
